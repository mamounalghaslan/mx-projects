# %%
# !pwd

# Dataset location
DATASET_LOCATION = '/workspace/yolov8-b'
# Out:
# /workspace

# %%
# Install dependencies
# !pip install ultralytics
# !export MKL_THREADING_LAYER=GNU
# !export MKL_SERVICE_FORCE_INTEL=1
# !pip install --upgrade numpy mkl-service

# Import dependencies
from IPython import display

# Clear previous output
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.13 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# Setup complete ✅ (128 CPUs, 472.2 GB RAM, 1.2/16.0 GB disk)

# %%
# !yolo task=detect mode=train model=yolov9c.pt data={DATASET_LOCATION}/data.yaml epochs=5 imgsz=640 device=0,1,2,3,4,5,6,7
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.13 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:1 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:2 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:3 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:4 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:5 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:6 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:7 (NVIDIA GeForce RTX 4090, 24217MiB)
# ...
