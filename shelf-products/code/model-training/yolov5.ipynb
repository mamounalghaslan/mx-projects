# %%
# Dataset location
DATASET_LOCATION = '/notebooks/yolov5/Shelf-Monitoring-A'

# Cloning YOLOV5 repo
# !git clone https://github.com/ultralytics/yolov5

# Installing requirements
# %cd /notebooks/yolov5
# %pip install -qr requirements.txt comet_ml

# Importing libraries
import utils

# Checking if GPU is available
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (Quadro P6000, 24443MiB)
# Setup complete ✅ (8 CPUs, 29.4 GB RAM, 114.5/244.2 GB disk)

# %%
# Training the model with a size of 640x640, batch size of 16 and 200 epochs, using the yolov5 medium (yolov5m.pt) weights

# !python train.py --img 640 --batch 16 --epochs 200 --data {DATASET_LOCATION}/data.yaml --weights yolov5m.pt
# Out:
# train: weights=yolov5m.pt, cfg=, data=/notebooks/yolov5/Shelf-Monitoring-A/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (Quadro P6000, 24443MiB)
#
# ...

# %%
# !python detect.py --weights 'runs/train/exp18/weights/best.pt' --img 640 --conf 0.25 --source {DATASET_LOCATION}/test/images
# Out:
# detect: weights=['runs/train/exp18/weights/best.pt'], source=/notebooks/yolov5/Shelf-Monitoring-A/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (Quadro P6000, 24443MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
# image 1/40 /notebooks/yolov5/Shelf-Monitoring-A/test/images/20231030_073112_jpg.rf.889b4bf54054a064d71ec4b7894c24aa.jpg: 640x640 152 Products, 13.0ms
# ...

# %%
# Testing the model with a input image size of 640x640 using the best weights from the training and the test images from the dataset

# !python val.py --weights 'runs/train/exp18/weights/best.pt' --data {DATASET_LOCATION}/data.yaml --img 640 --task test --name 'YOLOv5TEST'
# Out:
# val: data=/notebooks/yolov5/Shelf-Monitoring-A/data.yaml, weights=['runs/train/exp18/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=YOLOv5TEST, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (Quadro P6000, 24443MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
# test: Scanning /notebooks/yolov5/Shelf-Monitoring-A/test/labels... 40 images, 0
# test: New cache created: /notebooks/yolov5/Shelf-Monitoring-A/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all         40       6020      0.362      0.408       0.55      0.416
# ...
